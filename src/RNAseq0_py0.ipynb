# %%
"""
Avi Shah, 11/14/2022. Yang Lab NJMS

This script traverses the direct download
from Illumina's basespace and generates scripts
that can be run to align reads to a given reference
genome.
"""

import os
import pandas as pd
import numpy as np
import scipy

# we need to get to scratch space; we start on jupyter
# all of the files from Illumina's basespace were
# downloaded to /scratch/as2654/RNAseq0 using
# the basespace CLI on Amarel
scrpath = os.path.join("/scratch", "as2654", "RNAseq0")
print(scrpath)
os.chdir(scrpath)

# OS walk the download folder as root to ensure
# that all gzipped sequencing files are present;
# also have indices/annot for tuberculosis and coli.
# NOTE: indices exported to BOWTIE2_INDEXES global var
for root, subdirs, files in os.walk("."):
    print(root)
    print("\n", len(subdirs))
    for sd in subdirs:
        print(sd)
    print()
    for f in files:
        print(f)
# Out:
# /scratch/as2654/RNAseq0
# .
#
#  86
# 11_L002_ds.9f49b088c9f74001b79064567d253a75
# 10_L002_ds.a94c1831f6d444e1855bbaad85082f0d
# 3_L002_ds.ba6aafd4e2ba43c485c280fb4ec5e79e
# 34_L001_ds.bf7127527551495fa1a4a58ca519903b
# 23_L001_ds.a33e5b8d9f7a4ed8bc31553c2c2da2d7
# 7_L001_ds.51ddfbd5a90f471eb55080bfc0aea372
# 18_L002_ds.350e25fc4a7e484293ae4b9a9767dcaa
# 12_L001_ds.7f8e264de73747d3894f21f9e8788339
# 25_L002_ds.929b45e3d4264bd49781dac51853d598
# 1_L001_ds.1969ed4d36b04971be773b320148a85b
# 14_L002_ds.322d5950daa448f088d0bbf4fa53f7a4
# 24_L002_ds.66df139c925b4bb382f335ed03d37bc6
# 3_L001_ds.0c295149fece4fddbe13631e39190018
# 8_L002_ds.1dd835d2dd6c44dba2dd59d512876bb2
# 33_L001_ds.38f7687b4bc046dda7c91dd3e3e6f056
# 16_L001_ds.41803543209b41f58820a74b825b7922
# 25_L001_ds.4de6e9a3462945baaaf13467a366303b
# 8_L001_ds.5863f1a569bc4a889c66aca8753b2ca9
# 17_L002_ds.1ea009361d5b41229933ceaef034f26a
# 18_L001_ds.3def297ea83a453cbb30684d6b865bc8
# 22_L002_ds.5d9fd11530f94f9e9979d7fb10f445df
# 23_L002_ds.df591ff5fa944bd7858188c9076147f3
# 16_L002_ds.e62ced3e7e414eed8daa5597010a5890
# 23_L001_ds.021d93d3c256467b90d09a2919d64b4b
# 13_L002_ds.14615e60d1c64eeea61cdd746c35125d
# 35_L002_ds.006a4b0fa70b4d068a468b45bfbe7a2d
# 9_L002_ds.28c347e5776244d79e4ce694119a224e
# 34_L002_ds.74aa1510707e4185b756bf7320a12882
# 5_L001_ds.2b391e8072b942c0888578f7b5cd0b57
# 18_L001_ds.31f7e4521f9f4dde82e7d28d311c92a3
# 30_L001_ds.f44a0f4d1bff4aa1bcf0f999a4b6f030
# 9_L001_ds.841f69ddd94f4f7ebc1f55f637bdb9e4
# 19_L001_ds.a97e1d2d443c43d5b8f8b8826284211b
# 29_L001_ds.1c58887e5e174024bb7587616ef06dca
# 6_L001_ds.106426061eab4bde98528d6f3e6712ca
# 4_L002_ds.e48c5e53b4db4da2a58cc719dba71bd2
# 6_L002_ds.1389d72868ff4bc48765e65ad920f769
# 22_L001_ds.4f6e9f9c22ea4c669b87059cfde14a44
#
# ecoli.1.bt2
# H37Rv_Alland.3.bt2
# 221104_Yang_RNAseq_371529552.json
# process_RNAseq0_0.sh
# H37Rv_Alland.rev.2.bt2
# process_RNAseq0_3.sh
# Yang_3.log.txt
# H37Rv_Alland.1.bt2
# H37Rv_Alland.2.bt2
# run_pipeline.sh
# H37Rv_Alland.rev.1.bt2
# H37Rv_Alland.4.bt2
# RV1_S18_L002.bowtie2stats
# process_RNAseq0_4.sh
# RV1_S18_L002_R2_001_fastqc.zip
# ecoli.fna
# ecoli.4.bt2
# process_RNAseq0_1.sh
# Yang_5.log.txt
# Yang_2.log.txt
# RNAseq0_controller.sh
# Yang_0.log.txt
# H37Rv_Alland.gtf
# process_RNAseq0_2.sh
# RV1_S18_L002_R1_001_fastqc.zip
# Yang_4.log.txt
# ecoli.gtf
# index.csv
# ecoli.rev.2.bt2
# Yang_1.log.txt
# ecoli.3.bt2
# process_reads.sh
# ecoli.rev.1.bt2
# ecoli.2.bt2
# process_RNAseq0_5.sh
# ./11_L002_ds.9f49b088c9f74001b79064567d253a75
#
#  0
#
# IR3_S11_L002_R2_001.fastq.gz
# IR3_S11_L002_R1_001.fastq.gz
# ./10_L002_ds.a94c1831f6d444e1855bbaad85082f0d
#
#  0
#
# IR2_S10_L002_R1_001.fastq.gz
# IR2_S10_L002_R2_001.fastq.gz
# ./3_L002_ds.ba6aafd4e2ba43c485c280fb4ec5e79e
#
#  0
#
# CTL3_S3_L002_R1_001.fastq.gz
# CTL3_S3_L002_R2_001.fastq.gz
# ./34_L001_ds.bf7127527551495fa1a4a58ca519903b
#
#  0
#
# atpA2-BL_S34_L001_R1_001.fastq.gz
# atpA2-BL_S34_L001_R2_001.fastq.gz
# ./23_L001_ds.a33e5b8d9f7a4ed8bc31553c2c2da2d7
#
#  0
#
# RV6_S23_L001_R2_001.fastq.gz
# RV6_S23_L001_R1_001.fastq.gz
# ./7_L001_ds.51ddfbd5a90f471eb55080bfc0aea372
#
#  0
#
# IB2_S7_L001_R2_001.fastq.gz
# IB2_S7_L001_R1_001.fastq.gz
# ./18_L002_ds.350e25fc4a7e484293ae4b9a9767dcaa
#
#  0
#
# RV1_S18_L002_R1_001.fastq.gz
# RV1_S18_L002_R2_001.fastq.gz
# ./12_L001_ds.7f8e264de73747d3894f21f9e8788339
#
#  0
#
# IC1_S12_L001_R1_001.fastq.gz
# IC1_S12_L001_R2_001.fastq.gz
# ./25_L002_ds.929b45e3d4264bd49781dac51853d598
#
#  0
#
# KG2_S25_L002_R1_001.fastq.gz
# KG2_S25_L002_R2_001.fastq.gz
# ./1_L001_ds.1969ed4d36b04971be773b320148a85b
#
#  0
#
# CTL1_S1_L001_R2_001.fastq.gz
# CTL1_S1_L001_R1_001.fastq.gz
# ./14_L002_ds.322d5950daa448f088d0bbf4fa53f7a4
#
#  0
#
# IC3_S14_L002_R1_001.fastq.gz
# IC3_S14_L002_R2_001.fastq.gz
# ./24_L002_ds.66df139c925b4bb382f335ed03d37bc6
#
#  0
#
# KG1_S24_L002_R1_001.fastq.gz
# KG1_S24_L002_R2_001.fastq.gz
# ./3_L001_ds.0c295149fece4fddbe13631e39190018
#
#  0
#
# CTL3_S3_L001_R2_001.fastq.gz
# CTL3_S3_L001_R1_001.fastq.gz
# ./8_L002_ds.1dd835d2dd6c44dba2dd59d512876bb2
#
#  0
#
# IB3_S8_L002_R1_001.fastq.gz
# IB3_S8_L002_R2_001.fastq.gz
# ./33_L001_ds.38f7687b4bc046dda7c91dd3e3e6f056
#
#  0
#
# atpA1-BL_S33_L001_R2_001.fastq.gz
# atpA1-BL_S33_L001_R1_001.fastq.gz
# ./16_L001_ds.41803543209b41f58820a74b825b7922
#
#  0
#
# IQ2_S16_L001_R1_001.fastq.gz
# IQ2_S16_L001_R2_001.fastq.gz
# ./25_L001_ds.4de6e9a3462945baaaf13467a366303b
#
#  0
#
# KG2_S25_L001_R2_001.fastq.gz
# KG2_S25_L001_R1_001.fastq.gz
# ./8_L001_ds.5863f1a569bc4a889c66aca8753b2ca9
#
#  0
#
# IB3_S8_L001_R1_001.fastq.gz
# IB3_S8_L001_R2_001.fastq.gz
# ./17_L002_ds.1ea009361d5b41229933ceaef034f26a
#
#  0
#
# IQ3_S17_L002_R1_001.fastq.gz
# IQ3_S17_L002_R2_001.fastq.gz
# ./18_L001_ds.3def297ea83a453cbb30684d6b865bc8
#
#  0
#
# RV1_S18_L001_R2_001.fastq.gz
# RV1_S18_L001_R1_001.fastq.gz
# ./22_L002_ds.5d9fd11530f94f9e9979d7fb10f445df
#
#  0
#
# RV5_S22_L002_R2_001.fastq.gz
# RV5_S22_L002_R1_001.fastq.gz
# ./23_L002_ds.df591ff5fa944bd7858188c9076147f3
#
#  0
#
# RV6_S23_L002_R2_001.fastq.gz
# RV6_S23_L002_R1_001.fastq.gz
# ./16_L002_ds.e62ced3e7e414eed8daa5597010a5890
#
#  0
#
# IQ2_S16_L002_R2_001.fastq.gz
# IQ2_S16_L002_R1_001.fastq.gz
# ./23_L001_ds.021d93d3c256467b90d09a2919d64b4b
#
#  0
#
# RV6_S23_L001_R2_001.fastq.gz
# RV6_S23_L001_R1_001.fastq.gz
# ./13_L002_ds.14615e60d1c64eeea61cdd746c35125d
#
#  0
#
# IC2_S13_L002_R2_001.fastq.gz
# IC2_S13_L002_R1_001.fastq.gz
# ./35_L002_ds.006a4b0fa70b4d068a468b45bfbe7a2d
#
#  0
#
# atpA3-BL_S35_L002_R1_001.fastq.gz
# atpA3-BL_S35_L002_R2_001.fastq.gz
# ./9_L002_ds.28c347e5776244d79e4ce694119a224e
#
#  0
#
# IR1_S9_L002_R2_001.fastq.gz
# IR1_S9_L002_R1_001.fastq.gz
# ./34_L002_ds.74aa1510707e4185b756bf7320a12882
#
#  0
#
# atpA2-BL_S34_L002_R2_001.fastq.gz
# atpA2-BL_S34_L002_R1_001.fastq.gz
# ./5_L001_ds.2b391e8072b942c0888578f7b5cd0b57
#
#  0
#
# I3_S5_L001_R1_001.fastq.gz
# I3_S5_L001_R2_001.fastq.gz
# ./18_L001_ds.31f7e4521f9f4dde82e7d28d311c92a3
#
#  0
#
# RV1_S18_L001_R2_001.fastq.gz
# RV1_S18_L001_R1_001.fastq.gz
# ./30_L001_ds.f44a0f4d1bff4aa1bcf0f999a4b6f030
#
#  0
#
# WT1-BL_S30_L001_R2_001.fastq.gz
# WT1-BL_S30_L001_R1_001.fastq.gz
# ./9_L001_ds.841f69ddd94f4f7ebc1f55f637bdb9e4
#
#  0
#
# IR1_S9_L001_R1_001.fastq.gz
# IR1_S9_L001_R2_001.fastq.gz
# ./19_L001_ds.a97e1d2d443c43d5b8f8b8826284211b
#
#  0
#
# RV2_S19_L001_R1_001.fastq.gz
# RV2_S19_L001_R2_001.fastq.gz
# ./29_L001_ds.1c58887e5e174024bb7587616ef06dca
#
#  0
#
# KG6_S29_L001_R2_001.fastq.gz
# KG6_S29_L001_R1_001.fastq.gz
# ./6_L001_ds.106426061eab4bde98528d6f3e6712ca
#
#  0
#
# IB1_S6_L001_R2_001.fastq.gz
# IB1_S6_L001_R1_001.fastq.gz
# ./4_L002_ds.e48c5e53b4db4da2a58cc719dba71bd2
#
#  0
#
# I2_S4_L002_R2_001.fastq.gz
# I2_S4_L002_R1_001.fastq.gz
# ./15_L001_ds.c2cd7256f3c84435a8c4552817e54634
#
#  0
#
# IQ1_S15_L001_R2_001.fastq.gz
# IQ1_S15_L001_R1_001.fastq.gz
# ./22_L001_ds.a2a8a0d1c1854555889b257a9aad58ed
#
#  0
#
# RV5_S22_L001_R1_001.fastq.gz
# RV5_S22_L001_R2_001.fastq.gz
# ./10_L001_ds.a66bd56633524b1a9b2b838ff5c99275
#
#  0
#
# IR2_S10_L001_R1_001.fastq.gz
# IR2_S10_L001_R2_001.fastq.gz
# ./32_L001_ds.1414e4a98dc8477f8621e8338c603882
#
#  0
#
# WT3-BL_S32_L001_R1_001.fastq.gz
# WT3-BL_S32_L001_R2_001.fastq.gz
# ./15_L002_ds.745103b02b3745c18925a8187de11e75
#
#  0
#
# IQ1_S15_L002_R2_001.fastq.gz
# IQ1_S15_L002_R1_001.fastq.gz
# ./20_L001_ds.4c1b80bea47c407896414c282b43999a
#
#  0
#
# RV3_S20_L001_R1_001.fastq.gz
# RV3_S20_L001_R2_001.fastq.gz
# ./33_L001_ds.f79c7b34398a4be4be34162a2aee39e3
#
#  0
#
# atpA1-BL_S33_L001_R2_001.fastq.gz
# atpA1-BL_S33_L001_R1_001.fastq.gz
# ./27_L001_ds.f8c4844b17014536b35eb3b5b904b398
#
#  0
#
# KG4_S27_L001_R2_001.fastq.gz
# KG4_S27_L001_R1_001.fastq.gz
# ./27_L002_ds.b75d7c1b1dcf477fb27686cfaa5bb78a
#
#  0
#
# KG4_S27_L002_R1_001.fastq.gz
# KG4_S27_L002_R2_001.fastq.gz
# ./31_L002_ds.2b5956e773e1484383ccc15d8927f6f4
#
#  0
#
# WT2-BL_S31_L002_R1_001.fastq.gz
# WT2-BL_S31_L002_R2_001.fastq.gz
# ./11_L001_ds.552cf8b6a9fa4504a2d4288c2f9fdd59
#
#  0
#
# IR3_S11_L001_R2_001.fastq.gz
# IR3_S11_L001_R1_001.fastq.gz
# ./9_L001_ds.9ed821596b884977abebb5e0a6a1d44b
#
#  0
#
# IR1_S9_L001_R1_001.fastq.gz
# IR1_S9_L001_R2_001.fastq.gz
# ./2_L001_ds.0167ab5e6d1248a5a776dcc26c287132
#
#  0
#
# CTL2_S2_L001_R1_001.fastq.gz
# CTL2_S2_L001_R2_001.fastq.gz
# ./13_L001_ds.fce50d997e2a4e219a813993f69d5d72
#
#  0
#
# IC2_S13_L001_R1_001.fastq.gz
# IC2_S13_L001_R2_001.fastq.gz
# ./30_L002_ds.0b9a8bc3dfdc499e9bcbb443bde06f5f
#
#  0
#
# WT1-BL_S30_L002_R2_001.fastq.gz
# WT1-BL_S30_L002_R1_001.fastq.gz
# ./7_L002_ds.779fbc54704a4cf1adec097fd251f71b
#
#  0
#
# IB2_S7_L002_R2_001.fastq.gz
# IB2_S7_L002_R1_001.fastq.gz
# ./1_L002_ds.fd188b43399349049490b40bdc612cd6
#
#  0
#
# CTL1_S1_L002_R2_001.fastq.gz
# CTL1_S1_L002_R1_001.fastq.gz
# ./36_L001_ds.b9ebf1b63fdb4bb8947339231fe29d97
#
#  0
#
# I1_S36_L001_R1_001.fastq.gz
# I1_S36_L001_R2_001.fastq.gz
# ./28_L002_ds.c1f91e4ba3e547bab37eb643aeabb3b0
#
#  0
#
# KG5_S28_L002_R2_001.fastq.gz
# KG5_S28_L002_R1_001.fastq.gz
# ./5_L002_ds.9c55a0f54fa745a9a53a46d68db523f4
#
#  0
#
# I3_S5_L002_R1_001.fastq.gz
# I3_S5_L002_R2_001.fastq.gz
# ./21_L001_ds.ae9efb0530434058b4888a80c071e995
#
#  0
#
# RV4_S21_L001_R2_001.fastq.gz
# RV4_S21_L001_R1_001.fastq.gz
# ./16_L001_ds.65db1ec90ec644e1b20099f182af0f0b
#
#  0
#
# IQ2_S16_L001_R1_001.fastq.gz
# IQ2_S16_L001_R2_001.fastq.gz
# ./25_L001_ds.75f0916f97ce4ab0ae381dde9fa42ec4
#
#  0
#
# KG2_S25_L001_R2_001.fastq.gz
# KG2_S25_L001_R1_001.fastq.gz
# ./8_L001_ds.0a223c8a9e6d49cbad51d0cf91e2b08c
#
#  0
#
# IB3_S8_L001_R1_001.fastq.gz
# IB3_S8_L001_R2_001.fastq.gz
# ./36_L002_ds.beab1c7cbb22456180186764fddc17d1
#
#  0
#
# I1_S36_L002_R1_001.fastq.gz
# I1_S36_L002_R2_001.fastq.gz
# ./2_L001_ds.ef79ec9c92284e6992e8766280c97725
#
#  0
#
# CTL2_S2_L001_R1_001.fastq.gz
# CTL2_S2_L001_R2_001.fastq.gz
# ./29_L002_ds.30d0de9f1bd4442f8d211a5e31b2516b
#
#  0
#
# KG6_S29_L002_R1_001.fastq.gz
# KG6_S29_L002_R2_001.fastq.gz
# ./14_L001_ds.65458b6be1df4cd59dd41852cdd09877
#
#  0
#
# IC3_S14_L001_R2_001.fastq.gz
# IC3_S14_L001_R1_001.fastq.gz
# ./17_L001_ds.d9eb548b641f4544a65d2969ddc49121
#
#  0
#
# IQ3_S17_L001_R2_001.fastq.gz
# IQ3_S17_L001_R1_001.fastq.gz
# ./35_L001_ds.72b9f9ce94ca40f1ac390b889fade79b
#
#  0
#
# atpA3-BL_S35_L001_R1_001.fastq.gz
# atpA3-BL_S35_L001_R2_001.fastq.gz
# ./4_L001_ds.17c0c0ccde90429aaf082e66eb028dbd
#
#  0
#
# I2_S4_L001_R2_001.fastq.gz
# I2_S4_L001_R1_001.fastq.gz
# ./26_L001_ds.bec5e32bfc7140aea03d779dedf67c1c
#
#  0
#
# KG3_S26_L001_R2_001.fastq.gz
# KG3_S26_L001_R1_001.fastq.gz
# ./32_L002_ds.03d2d07292b54328b39f3e945727b680
#
#  0
#
# WT3-BL_S32_L002_R2_001.fastq.gz
# WT3-BL_S32_L002_R1_001.fastq.gz
# ./5_L001_ds.a3a337e243894d33886181b9d4af4e67
#
#  0
#
# I3_S5_L001_R1_001.fastq.gz
# I3_S5_L001_R2_001.fastq.gz
# ./26_L002_ds.85f170d95f8c43efbc948d3a525c3231
#
#  0
#
# KG3_S26_L002_R2_001.fastq.gz
# KG3_S26_L002_R1_001.fastq.gz
# ./21_L001_ds.4589c1c44347415f9c8d8024e43b7791
#
#  0
#
# RV4_S21_L001_R2_001.fastq.gz
# RV4_S21_L001_R1_001.fastq.gz
# ./15_L001_ds.901a7d1ab83b41c381a796dd1ea4d5dc
#
#  0
#
# IQ1_S15_L001_R2_001.fastq.gz
# IQ1_S15_L001_R1_001.fastq.gz
# ./28_L001_ds.20d5a7a322f142e5800d18442c2a86e4
#
#  0
#
# KG5_S28_L001_R2_001.fastq.gz
# KG5_S28_L001_R1_001.fastq.gz
# ./31_L001_ds.0c005a38bfeb4924ba6da5a275f4aa11
#
#  0
#
# WT2-BL_S31_L001_R1_001.fastq.gz
# WT2-BL_S31_L001_R2_001.fastq.gz
# ./2_L002_ds.6a62980a7b5d4bb1bd1027eaac0b1ad1
#
#  0
#
# CTL2_S2_L002_R1_001.fastq.gz
# CTL2_S2_L002_R2_001.fastq.gz
# ./7_L001_ds.c51bd4843fb54e5dba70548cf498400f
#
#  0
#
# IB2_S7_L001_R2_001.fastq.gz
# IB2_S7_L001_R1_001.fastq.gz
# ./19_L002_ds.e6a40ed5cf6643cfad8d02017a1a413d
#
#  0
#
# RV2_S19_L002_R1_001.fastq.gz
# RV2_S19_L002_R2_001.fastq.gz
# ./20_L002_ds.36cade6bbeb54f4b9ddeb5f7a79c5ff8
#
#  0
#
# RV3_S20_L002_R1_001.fastq.gz
# RV3_S20_L002_R2_001.fastq.gz
# ./12_L002_ds.3dc9851adeba4b8a89fd5aaa289e87ee
#
#  0
#
# IC1_S12_L002_R2_001.fastq.gz
# IC1_S12_L002_R1_001.fastq.gz
# ./24_L001_ds.94a7c15a57d94f788c8c3781adcdd9cb
#
#  0
#
# KG1_S24_L001_R2_001.fastq.gz
# KG1_S24_L001_R1_001.fastq.gz
# ./21_L002_ds.0407b59d8d5b4599b18c2fde66b1cc6a
#
#  0
#
# RV4_S21_L002_R1_001.fastq.gz
# RV4_S21_L002_R2_001.fastq.gz
# ./33_L002_ds.78792822f08a43359bc6179a64fe1605
#
#  0
#
# atpA1-BL_S33_L002_R1_001.fastq.gz
# atpA1-BL_S33_L002_R2_001.fastq.gz
# ./13_L001_ds.83aa83d0c55348b787766f0afd7b82a6
#
#  0
#
# IC2_S13_L001_R1_001.fastq.gz
# IC2_S13_L001_R2_001.fastq.gz
# ./6_L002_ds.1389d72868ff4bc48765e65ad920f769
#
#  0
#
# IB1_S6_L002_R1_001.fastq.gz
# IB1_S6_L002_R2_001.fastq.gz
# ./22_L001_ds.4f6e9f9c22ea4c669b87059cfde14a44
#
#  0
#
# RV5_S22_L001_R1_001.fastq.gz
# RV5_S22_L001_R2_001.fastq.gz

# %%
# get the index of files provided by genomics crew

import pandas as pd

# this is the first sheet from:
# "Illumina Library Submission_Yang_101222_Index.xlsx"
# saved as csv
indices = pd.read_csv("index.csv")

for row, data in indices.items():
    print(row)
    for key, value in data.items():
        print(key, value)
# Out:
# Well
# 0 A1
# 1 B1
# 2 C1
# 3 D1
# 4 E1
# 5 F1
# 6 G1
# 7 H1
# 8 A2
# 9 B2
# 10 C2
# 11 D2
# 12 E2
# 13 F2
# 14 G2
# 15 H2
# 16 A3
# 17 B3
# 18 C3
# 19 D3
# 20 E3
# 21 F3
# 22 G3
# 23 H3
# 24 A4
# 25 B4
# 26 C4
# 27 D4
# 28 E4
# 29 F4
# 30 G4
# 31 H4
# 32 A5
# 33 B5
# 34 C5
# 35 nan
# 36 Separate:
# 37 nan
# 38 NEB Oligos: https://www.neb.com/-/media/nebus/files/manuals/manuale6609.pdf
# Sample Name
# 0 CTL1
# 1 CTL2
# 2 CTL3
# 3 I2
# 4 I3
# 5 IB1
# 6 IB2
# 7 IB3
# 8 IR1
# 9 IR2
# 10 IR3
# 11 IC1
# 12 IC2
# 13 IC3
# 14 IQ1
# 15 IQ2
# 16 IQ3
# 17 RV1
# 18 RV2
# 19 RV3
# 20 RV4
# 21 RV5
# 22 RV6
# 23 KG1
# 24 KG2
# 25 KG3
# 26 KG4
# 27 KG5
# 28 KG6
# 29 WT1-BL
# 30 WT2-BL
# 31 WT3-BL
# 32 atpA1-BL
# 33 atpA2-BL
# 34 atpA3-BL
# 35 nan
# 36 I1
# 37 nan
# 38 nan
# NEB Oligos Well
# 0 A2
# 1 B2
# 2 C2
# 3 D2
# 4 E2
# 5 F2
# 6 G2
# 7 H2
# 8 A3
# 9 B3
# 10 C3
# 11 D3
# 12 E3
# 13 F3
# 14 G3
# 15 H3
# 16 A4
# 17 B4
# 18 C4
# 19 D4
# 20 E4
# 21 F4
# 22 G4
# 23 H4
# 24 A5
# 25 B5
# 26 C5
# 27 D5
# 28 E5
# 29 F5
# 30 G5
# 31 H5
# 32 D1
# 33 E1
# 34 F1
# 35 nan
# 36 A1
# 37 nan
# 38 nan
# NEB Oligos Primer
# 0 P2
# 1 P14
# 2 P26
# 3 P38
# 4 P50
# 5 P62
# 6 P74
# 7 P86
# 8 P3
# 9 P15
# 10 P27
# 11 P39
# 12 P51
# 13 P63
# 14 P75
# 15 P87
# 16 P4
# 17 P16
# 18 P28
# 19 P40
# 20 P52
# 21 P64
# 22 P76
# 23 P88
# 24 P5
# 25 P17
# 26 P29
# 27 P41
# 28 P53
# 29 P65
# 30 P77
# 31 P89
# 32 P37
# 33 P49
# 34 P61
# 35 nan
# 36 P1
# 37 nan
# 38 nan
# Organism
# 0 M. tuberculosis H37Rv
# 1 M. tuberculosis H37Rv
# 2 M. tuberculosis H37Rv
# 3 M. tuberculosis H37Rv
# 4 M. tuberculosis H37Rv
# 5 M. tuberculosis H37Rv
# 6 M. tuberculosis H37Rv
# 7 M. tuberculosis H37Rv
# 8 M. tuberculosis H37Rv
# 9 M. tuberculosis H37Rv
# 10 M. tuberculosis H37Rv
# 11 M. tuberculosis H37Rv
# 12 M. tuberculosis H37Rv
# 13 M. tuberculosis H37Rv
# 14 M. tuberculosis H37Rv
# 15 M. tuberculosis H37Rv
# 16 M. tuberculosis H37Rv
# 17 M. tuberculosis H37Rv
# 18 M. tuberculosis H37Rv
# 19 M. tuberculosis H37Rv
# 20 M. tuberculosis H37Rv
# 21 M. tuberculosis H37Rv
# 22 M. tuberculosis H37Rv
# 23 M. tuberculosis H37Rv
# 24 M. tuberculosis H37Rv
# 25 M. tuberculosis H37Rv
# 26 M. tuberculosis H37Rv
# 27 M. tuberculosis H37Rv
# 28 M. tuberculosis H37Rv
# 29 E. coli MG1655
# 30 E. coli MG1656
# 31 E. coli MG1657
# 32 E. coli MG1658
# 33 E. coli MG1659
# 34 E. coli MG1660
# 35 nan
# 36 M. tuberculosis H37Rv
# 37 nan
# 38 nan
# Index
# 0 AGTGACCT
# 1 AGCCTATC
# 2 TCATCTCC
# 3 CCAGTATC
# 4 TTGCGAGA
# 5 GAACGAAG
# 6 CGAATTGC
# 7 GGAAGAGA
# 8 TCGGATTC
# 9 CTGTACCA
# 10 GAGAGTAC
# 11 TCTACGCA
# 12 GCAATTCC
# 13 CTCAGAAG
# 14 GTCCTAAG
# 15 GCGTTAGA
# 16 CAAGGTAC
# 17 AGACCTTG
# 18 GTCGTTAC
# 19 GTAACCGA
# 20 GAATCCGT
# 21 CATGAGCA
# 22 CTTAGGAC
# 23 ATCTGACC
# 24 TCCTCATG
# 25 AGGATAGC
# 26 GGAGGAAT
# 27 GACGTCAT
# 28 CCGCTTAA
# 29 GACGAACT
# 30 TCCACGTT
# 31 AACCAGAG
# 32 TACGGTCT
# 33 AAGACCGT
# 34 CAGGTTCA
# 35 nan
# 36 TTACCGAC
# 37 nan
# 38 nan

# %%
import math
import csv

# cross reference the index and the data downloaded from
# Illumina's basespace to make sure all the files are there
# and enforce that the names should match

# first i will collect sample names

sample_mdmap = dict()

# save all the sample names and the organism they came from
with open("index.csv") as csvf:
    reader = csv.reader(csvf, delimiter=",")
    for i, line in enumerate(reader):
        #print('line[{}] = {}'.format(i, line))
        orgstr = ""
        if line[4].startswith("M. tuberculosis"):
            orgstr = "mtb"            
        elif line[4].startswith("E. coli"):
            orgstr = "ecoli"
        #print(line[1], orgstr)
        if orgstr:
            #print(i)
            sample_mdmap[line[1]] = orgstr

for sample_name, organism in sample_mdmap.items():
    print(sample_name, organism)

print(len(sample_mdmap.items()))
# Out:
# CTL1 mtb
# CTL2 mtb
# CTL3 mtb
# I2 mtb
# I3 mtb
# IB1 mtb
# IB2 mtb
# IB3 mtb
# IR1 mtb
# IR2 mtb
# IR3 mtb
# IC1 mtb
# IC2 mtb
# IC3 mtb
# IQ1 mtb
# IQ2 mtb
# IQ3 mtb
# RV1 mtb
# RV2 mtb
# RV3 mtb
# RV4 mtb
# RV5 mtb
# RV6 mtb
# KG1 mtb
# KG2 mtb
# KG3 mtb
# KG4 mtb
# KG5 mtb
# KG6 mtb
# WT1-BL ecoli
# WT2-BL ecoli
# WT3-BL ecoli
# atpA1-BL ecoli
# atpA2-BL ecoli
# atpA3-BL ecoli
# I1 mtb
# 36

# %%
# now I will traverse the download and collect names

dl_names = []

# we need to ignore data from the fastq generate that took
# place on 11/7; we want only the data from 11/5

# the files from 11/7 are much smaller; detect by size

# NOTE: met with Dr. Yang 11/14/2022, small files are from
# a failed fastq generation run, do not process

# save the filename pair and their combined size
pairs = []

# save specifically the ones with real data
process_pairs = []

os.chdir(scrpath)
for fn0 in os.listdir("."):
    # generate absolute path for each
    fn0_ap = os.path.join(scrpath, fn0)
    # if it's a subdirectory, it may have my gzipped reads
    if os.path.isdir(fn0_ap):
        print(fn0_ap)
        pair = set(os.listdir(fn0_ap))
        pair_ap = []
        size = 0
        for fn1 in os.listdir(fn0_ap):
            print("   ", os.path.getsize(os.path.join(fn0_ap, fn1)) / 1e6, fn1)
            fn1_ap = os.path.join(fn0_ap, fn1)
            pair_ap.append(fn1_ap)
            size += os.path.getsize(fn1_ap) / 1e6
        pairs.append([pair, size])
        if size > 1200:
            dl_names.append(fn1.split("_")[0])
            process_pairs.append([pair_ap])
        print()

print(len(dl_names))
print(len(set(dl_names)))
# Out:
# /scratch/as2654/RNAseq0/11_L002_ds.9f49b088c9f74001b79064567d253a75
#     842.218075 IR3_S11_L002_R2_001.fastq.gz
#     805.421656 IR3_S11_L002_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/10_L002_ds.a94c1831f6d444e1855bbaad85082f0d
#     817.449538 IR2_S10_L002_R1_001.fastq.gz
#     910.150762 IR2_S10_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/3_L002_ds.ba6aafd4e2ba43c485c280fb4ec5e79e
#     870.013187 CTL3_S3_L002_R1_001.fastq.gz
#     919.083091 CTL3_S3_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/34_L001_ds.bf7127527551495fa1a4a58ca519903b
#     968.534159 atpA2-BL_S34_L001_R1_001.fastq.gz
#     1021.909132 atpA2-BL_S34_L001_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/23_L001_ds.a33e5b8d9f7a4ed8bc31553c2c2da2d7
#     925.52456 RV6_S23_L001_R2_001.fastq.gz
#     853.53278 RV6_S23_L001_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/7_L001_ds.51ddfbd5a90f471eb55080bfc0aea372
#     0.000668 IB2_S7_L001_R2_001.fastq.gz
#     0.000641 IB2_S7_L001_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/18_L002_ds.350e25fc4a7e484293ae4b9a9767dcaa
#     665.998959 RV1_S18_L002_R1_001.fastq.gz
#     711.091366 RV1_S18_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/12_L001_ds.7f8e264de73747d3894f21f9e8788339
#     875.667203 IC1_S12_L001_R1_001.fastq.gz
#     935.445915 IC1_S12_L001_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0
L001_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/26_L002_ds.85f170d95f8c43efbc948d3a525c3231
#     651.229714 KG3_S26_L002_R2_001.fastq.gz
#     600.045114 KG3_S26_L002_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/21_L001_ds.4589c1c44347415f9c8d8024e43b7791
#     852.969733 RV4_S21_L001_R2_001.fastq.gz
#     802.916271 RV4_S21_L001_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/15_L001_ds.901a7d1ab83b41c381a796dd1ea4d5dc
#     853.407197 IQ1_S15_L001_R2_001.fastq.gz
#     773.895571 IQ1_S15_L001_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/28_L001_ds.20d5a7a322f142e5800d18442c2a86e4
#     1029.380337 KG5_S28_L001_R2_001.fastq.gz
#     922.281358 KG5_S28_L001_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/31_L001_ds.0c005a38bfeb4924ba6da5a275f4aa11
#     871.163979 WT2-BL_S31_L001_R1_001.fastq.gz
#     916.644672 WT2-BL_S31_L001_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/2_L002_ds.6a62980a7b5d4bb1bd1027eaac0b1ad1
#     824.456779 CTL2_S2_L002_R1_001.fastq.gz
#     886.559449 CTL2_S2_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/7_L001_ds.c51bd4843fb54e5dba70548cf498400f
#     817.776327 IB2_S7_L001_R2_001.fastq.gz
#     767.384994 IB2_S7_L001_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/19_L002_ds.e6a40ed5cf6643cfad8d02017a1a413d
#     923.191339 RV2_S19_L002_R1_001.fastq.gz
#     978.296717 RV2_S19_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/20_L002_ds.36cade6bbeb54f4b9ddeb5f7a79c5ff8
#     899.887226 RV3_S20_L002_R1_001.fastq.gz
#     947.831621 RV3_S20_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/12_L002_ds.3dc9851adeba4b8a89fd5aaa289e87ee
#     932.917943 IC1_S12_L002_R2_001.fastq.gz
#     877.457508 IC1_S12_L002_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/24_L001_ds.94a7c15a57d94f788c8c3781adcdd9cb
#     759.557742 KG1_S24_L001_R2_001.fastq.gz
#     692.337344 KG1_S24_L001_R1_001.fastq.gz
#
# /scratch/as2654/RNAseq0/21_L002_ds.0407b59d8d5b4599b18c2fde66b1cc6a
#     801.63854 RV4_S21_L002_R1_001.fastq.gz
#     848.43674 RV4_S21_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/33_L002_ds.78792822f08a43359bc6179a64fe1605
#     965.567978 atpA1-BL_S33_L002_R1_001.fastq.gz
#     1031.088168 atpA1-BL_S33_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/13_L001_ds.83aa83d0c55348b787766f0afd7b82a6
#     0.000405 IC2_S13_L001_R1_001.fastq.gz
#     0.000425 IC2_S13_L001_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/6_L002_ds.1389d72868ff4bc48765e65ad920f769
#     854.47783 IB1_S6_L002_R1_001.fastq.gz
#     911.950632 IB1_S6_L002_R2_001.fastq.gz
#
# /scratch/as2654/RNAseq0/22_L001_ds.4f6e9f9c22ea4c669b87059cfde14a44
#     848.924873 RV5_S22_L001_R1_001.fastq.gz
#     921.407481 RV5_S22_L001_R2_001.fastq.gz
#
# 72
# 36

# %%
# enforce that all sample names are present in both
# the genomics crew's index and the files that
# Illumina provided via basespace

genomics_names = [k for k, v in sample_mdmap.items()]
dl_names = dl_names
print(genomics_names, dl_names)
print(set(genomics_names) - set(dl_names))
print(set(dl_names) - set(genomics_names))
# these should BOTH print the empty set
# Out:
# ['CTL1', 'CTL2', 'CTL3', 'I2', 'I3', 'IB1', 'IB2', 'IB3', 'IR1', 'IR2', 'IR3', 'IC1', 'IC2', 'IC3', 'IQ1', 'IQ2', 'IQ3', 'RV1', 'RV2', 'RV3', 'RV4', 'RV5', 'RV6', 'KG1', 'KG2', 'KG3', 'KG4', 'KG5', 'KG6', 'WT1-BL', 'WT2-BL', 'WT3-BL', 'atpA1-BL', 'atpA2-BL', 'atpA3-BL', 'I1'] ['IR3', 'IR2', 'CTL3', 'atpA2-BL', 'RV6', 'RV1', 'IC1', 'KG2', 'CTL1', 'IC3', 'KG1', 'CTL3', 'IB3', 'IQ2', 'IQ3', 'RV5', 'RV6', 'IQ2', 'IC2', 'atpA3-BL', 'IR1', 'atpA2-BL', 'RV1', 'WT1-BL', 'IR1', 'RV2', 'KG6', 'IB1', 'I2', 'IR2', 'WT3-BL', 'IQ1', 'RV3', 'atpA1-BL', 'KG4', 'KG4', 'WT2-BL', 'IR3', 'IC2', 'WT1-BL', 'IB2', 'CTL1', 'I1', 'KG5', 'I3', 'KG2', 'IB3', 'I1', 'CTL2', 'KG6', 'IC3', 'IQ3', 'atpA3-BL', 'I2', 'KG3', 'WT3-BL', 'I3', 'KG3', 'RV4', 'IQ1', 'KG5', 'WT2-BL', 'CTL2', 'IB2', 'RV2', 'RV3', 'IC1', 'KG1', 'RV4', 'atpA1-BL', 'IB1', 'RV5']
# set()
# set()

# %%
# start building the submission files
# genomics crew demuxed and adapter trimmed
# the fastq files during fastq generation, 
# these steps are not incorporated in the 
# present pipeline. also see https://doi.org/10.1093/nargab/lqaa068

# main parameters for each job
n_cores     = 8
ram         = 16000 #MB
work_dir    = os.path.join("/mnt", "scratch")
save_dir    = os.path.join("/scratch", "as2654", "RNAseq0")
# bowtie2 index prefix, annotations (.gtf), and featureCounts feature
# for M. tubercolosis samples
bt2_mtb     = "H37Rv_Alland"
gtf_mtb     = os.path.join("/scratch", "as2654", "RNAseq0", "H37Rv_Alland.gtf")
fcpfx_mtb   = "transcript"
# for E. coli
bt2_ecoli   = "ecoli"
gtf_ecoli   = os.path.join("/scratch", "as2654", "RNAseq0", "ecoli.gtf")
fcpfx_ecoli = "gene"

n_nodes     = 6 # max number of active nodes
workload    = [[] for k in range(n_nodes)]

def get_filename(abspath):
    return abspath.split("/")[-1]

# make sure all the files are there (i should count to 72)
# and enforce 
i = 0
print(len(process_pairs))
for pair_idx in range(len(process_pairs)):
    pair = process_pairs[pair_idx]
    pair[0].sort(key=get_filename)
    rfor = pair[0][0].split("/")[-1]
    rrev = pair[0][1].split("/")[-1]
    unique_pfxfor = rfor.split("_R1_00")[0]
    unique_pfxrev = rrev.split("_R2_00")[0]
    sample_name = pair[0][0].split("/")[-1].split("_")[0]
    if unique_pfxfor == unique_pfxrev:
        #print(unique_pfxfor)
        i += 1
        # files verified 11/15/2022, 12:12pm
        command_list =  ["./process_reads.sh"] # $1
        command_list += [pair[0][0]]           # $2 etc.
        command_list += [pair[0][1]]
        command_list += [str(n_cores)]
        command_list += [str(ram)]
        command_list += [work_dir]
        command_list += [save_dir]
        if sample_mdmap[sample_name] == "mtb":
            command_list += [bt2_mtb]
            command_list += [gtf_mtb]
            command_list += [fcpfx_mtb]
        elif sample_mdmap[sample_name] == "ecoli":
            command_list += [bt2_ecoli]
            command_list += [gtf_ecoli]
            command_list += [fcpfx_ecoli]
        command_list += [unique_pfxfor]
        #print(" ".join(command_list))
        #print(pair_idx % n_nodes)
        workload[pair_idx % n_nodes].append(command_list)
print(i)


scripts = []

# move to where the work will be done
os.chdir(save_dir)

# make a SLURM request for each piece of work
# print the files here too, just to see what 
# they look like
for work_idx in range(len(workload)):
    work = workload[work_idx]
    print(len(work))
    script_name = "process_RNAseq0_" + str(work_idx) + ".sh"
    scripts.append(script_name)
    with open(script_name, "w") as script_loc:
        print(script_name)
        script_base =  ["#!/bin/bash"]
        script_base += ["#SBATCH --partition=main"]
        script_base += ["#SBATCH --requeue"]
        script_base += ["#SBATCH --job-name=Yang_" + str(work_idx) ]
        script_base += ["#SBATCH --ntasks=1"]
        script_base += ["#SBATCH --cpus-per-task=" + str(n_cores)]
        script_base += ["#SBATCH --mem=" + str(ram)]
        script_base += ["#SBATCH --time=36:00:00"]
        script_base += ["#SBATCH --output=Yang_" + str(work_idx) + ".log.txt"]
        for line in script_base:
            print(line)
            script_loc.write(line + "\n")
        for read_pair_instructions in work:
            line = " ".join(read_pair_instructions)
            print(line)
            script_loc.write(line + "\n")
        lastline = "exit"
        print(lastline)
        script_loc.write(lastline + "\n")
        
# finally write the master script to call the scripts
with open("RNAseq0_controller.sh", "w") as caller:
    caller.write("#!/bin/bash" + "\n")
    for script_name in scripts:
        line = "sbatch " + script_name 
        print(line)
        caller.write(line + "\n")
# Out:
# 72
# 72
# 12
# process_RNAseq0_0.sh
# #!/bin/bash
# #SBATCH --partition=main
# #SBATCH --requeue
# #SBATCH --job-name=Yang_0
# #SBATCH --ntasks=1
# #SBATCH --cpus-per-task=8
# #SBATCH --mem=16000
# #SBATCH --time=36:00:00
# #SBATCH --output=Yang_0.log.txt
# ./process_reads.sh /scratch/as2654/RNAseq0/11_L002_ds.9f49b088c9f74001b79064567d253a75/IR3_S11_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/11_L002_ds.9f49b088c9f74001b79064567d253a75/IR3_S11_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IR3_S11_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/12_L001_ds.7f8e264de73747d3894f21f9e8788339/IC1_S12_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/12_L001_ds.7f8e264de73747d3894f21f9e8788339/IC1_S12_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IC1_S12_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/8_L002_ds.1dd835d2dd6c44dba2dd59d512876bb2/IB3_S8_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/8_L002_ds.1dd835d2dd6c44dba2dd59d512876bb2/IB3_S8_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IB3_S8_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/13_L002_ds.14615e60d1c64eeea61cdd746c35125d/IC2_S13_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/13_L002_ds.14615e60d1c64eeea61cdd746c35125d/IC2_S13_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IC2_S13_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/9_L001_ds.841f69ddd94f4f7ebc1f55f637bdb9e4/IR1_S9_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/9_L001_ds.841f69ddd94f4f7ebc1f55f637bdb9e4/IR1_S9_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IR1_S9_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/32_L001_ds.1414e4a98dc8477f8621e8338c603882/WT3-BL_S32_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/32_L001_ds.1414e4a98dc8477f8621e8338c603882/WT3-BL_S32_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 ecoli /scratch/as2654/RNAseq0/ecoli.gtf gene WT3-BL_S32_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/31_L002_ds.2b5956e773e1484383ccc15d8927f6f4/WT2-BL_S31_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/31_L002_ds.2b5956e773e1484383ccc15d8927f6f4/WT2-BL_S31_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 ecoli /scratch/as2654/RNAseq0/ecoli.gtf gene WT2-BL_S31_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/36_L001_ds.b9ebf1b63fdb4bb8947339231fe29d97/I1_S36_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/36_L001_ds.b9ebf1b63fdb4bb8947339231fe29d97/I1_S36_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript I1_S36_L001
# ./process_reads.sh /scratch/as2654/RNAseq0
L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IB1_S6_L002
# exit
# 12
# process_RNAseq0_5.sh
# #!/bin/bash
# #SBATCH --partition=main
# #SBATCH --requeue
# #SBATCH --job-name=Yang_5
# #SBATCH --ntasks=1
# #SBATCH --cpus-per-task=8
# #SBATCH --mem=16000
# #SBATCH --time=36:00:00
# #SBATCH --output=Yang_5.log.txt
# ./process_reads.sh /scratch/as2654/RNAseq0/18_L002_ds.350e25fc4a7e484293ae4b9a9767dcaa/RV1_S18_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/18_L002_ds.350e25fc4a7e484293ae4b9a9767dcaa/RV1_S18_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript RV1_S18_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/3_L001_ds.0c295149fece4fddbe13631e39190018/CTL3_S3_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/3_L001_ds.0c295149fece4fddbe13631e39190018/CTL3_S3_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript CTL3_S3_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/16_L002_ds.e62ced3e7e414eed8daa5597010a5890/IQ2_S16_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/16_L002_ds.e62ced3e7e414eed8daa5597010a5890/IQ2_S16_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IQ2_S16_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/30_L001_ds.f44a0f4d1bff4aa1bcf0f999a4b6f030/WT1-BL_S30_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/30_L001_ds.f44a0f4d1bff4aa1bcf0f999a4b6f030/WT1-BL_S30_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 ecoli /scratch/as2654/RNAseq0/ecoli.gtf gene WT1-BL_S30_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/10_L001_ds.a66bd56633524b1a9b2b838ff5c99275/IR2_S10_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/10_L001_ds.a66bd56633524b1a9b2b838ff5c99275/IR2_S10_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IR2_S10_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/27_L002_ds.b75d7c1b1dcf477fb27686cfaa5bb78a/KG4_S27_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/27_L002_ds.b75d7c1b1dcf477fb27686cfaa5bb78a/KG4_S27_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript KG4_S27_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/1_L002_ds.fd188b43399349049490b40bdc612cd6/CTL1_S1_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/1_L002_ds.fd188b43399349049490b40bdc612cd6/CTL1_S1_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript CTL1_S1_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/36_L002_ds.beab1c7cbb22456180186764fddc17d1/I1_S36_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/36_L002_ds.beab1c7cbb22456180186764fddc17d1/I1_S36_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript I1_S36_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/4_L001_ds.17c0c0ccde90429aaf082e66eb028dbd/I2_S4_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/4_L001_ds.17c0c0ccde90429aaf082e66eb028dbd/I2_S4_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript I2_S4_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/15_L001_ds.901a7d1ab83b41c381a796dd1ea4d5dc/IQ1_S15_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/15_L001_ds.901a7d1ab83b41c381a796dd1ea4d5dc/IQ1_S15_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript IQ1_S15_L001
# ./process_reads.sh /scratch/as2654/RNAseq0/20_L002_ds.36cade6bbeb54f4b9ddeb5f7a79c5ff8/RV3_S20_L002_R1_001.fastq.gz /scratch/as2654/RNAseq0/20_L002_ds.36cade6bbeb54f4b9ddeb5f7a79c5ff8/RV3_S20_L002_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript RV3_S20_L002
# ./process_reads.sh /scratch/as2654/RNAseq0/22_L001_ds.4f6e9f9c22ea4c669b87059cfde14a44/RV5_S22_L001_R1_001.fastq.gz /scratch/as2654/RNAseq0/22_L001_ds.4f6e9f9c22ea4c669b87059cfde14a44/RV5_S22_L001_R2_001.fastq.gz 8 16000 /mnt/scratch /scratch/as2654/RNAseq0 H37Rv_Alland /scratch/as2654/RNAseq0/H37Rv_Alland.gtf transcript RV5_S22_L001
# exit
# sbatch process_RNAseq0_0.sh
# sbatch process_RNAseq0_1.sh
# sbatch process_RNAseq0_2.sh
# sbatch process_RNAseq0_3.sh
# sbatch process_RNAseq0_4.sh
# sbatch process_RNAseq0_5.sh
